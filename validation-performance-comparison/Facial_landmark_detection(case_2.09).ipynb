# %% [markdown]
# # (1) Dataset Visualization

# %%
import scipy.io as io
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf

# Set the random seed for TensorFlow
tf.random.set_seed(101)

# load the data
data = io.loadmat("face_landmark.mat")
images = data["images"]
landmarks = data["landmarks"]

print("im_shape:", images.shape)
print("landmarks_shape:", landmarks.shape)

np.random.seed(101)

fig, ax = plt.subplots(2, 2, figsize=(10,10))  # create a 2x2 grid of subplots
ax = ax.ravel()

for i in range(4):  # loop over the 4 subplots
    id = np.random.randint(len(images))  # generate a random index
    im = images[id]
    keypoints = landmarks[id]

    ax[i].imshow(im, cmap="gray")
    for point in keypoints:
        ax[i].plot(point[0], point[1], "r+")

plt.show()
# Out:
# im_shape: (2140, 96, 96)
# landmarks_shape: (2140, 15, 2)

# %% [markdown]
# # (2) Preprocessing

# %% [markdown]
# ### (2)-1. Data_split: train(60%), validation(20%), test(20%)

# %%
from sklearn.model_selection import train_test_split

# 60% training, 40% for validation/testing
train_images, val_test_images, train_landmarks, val_test_landmarks = train_test_split(images, landmarks, test_size=0.4, random_state=101)

# Split the 40% equally to validation and testing (20% each)
val_images, test_images, val_landmarks, test_landmarks = train_test_split(val_test_images, val_test_landmarks, test_size=0.5, random_state=101)

# reshape landmarks
train_landmarks = train_landmarks.reshape(-1, 30)
val_landmarks = val_landmarks.reshape(-1, 30)
test_landmarks = test_landmarks.reshape(-1, 30)

print("Training set:", train_images.shape, train_landmarks.shape)
print("Validation set:", val_images.shape, val_landmarks.shape)
print("Testing set:", test_images.shape, test_landmarks.shape)
# Out:
# Training set: (1284, 96, 96) (1284, 30)
# Validation set: (428, 96, 96) (428, 30)
# Testing set: (428, 96, 96) (428, 30)

# %% [markdown]
# ### (2)-2. Normalization & Reshaping

# %%
# Normalization
train_images = train_images / 255.0
val_images = val_images / 255.0
test_images = test_images / 255.0

# Scale landmarks
train_landmarks = train_landmarks / 96.0
val_landmarks = val_landmarks / 96.0
test_landmarks = test_landmarks / 96.0

# Reshaping
train_images = train_images.reshape(-1, 96, 96, 1)
val_images = val_images.reshape(-1, 96, 96, 1)
test_images = test_images.reshape(-1, 96, 96, 1)

print("After preprocessing:")
print("Training set:", train_images.shape, train_landmarks.shape)
print("Validation set:", val_images.shape, val_landmarks.shape)
print("Testing set:", test_images.shape, test_landmarks.shape)
# Out:
# After preprocessing:
# Training set: (1284, 96, 96, 1) (1284, 30)
# Validation set: (428, 96, 96, 1) (428, 30)
# Testing set: (428, 96, 96, 1) (428, 30)

# %%
# Find the range of the landmarks coordinates
landmarks_range_train = np.ptp(train_landmarks, axis=0)
landmarks_range_val = np.ptp(val_landmarks, axis=0)
landmarks_range_test = np.ptp(test_landmarks, axis=0)

print("Range of x coordinates in train data: ", landmarks_range_train[::2])
print("Range of y coordinates in train data: ", landmarks_range_train[1::2])

print("Range of x coordinates in validation data: ", landmarks_range_val[::2])
print("Range of y coordinates in validation data: ", landmarks_range_val[1::2])

print("Range of x coordinates in test data: ", landmarks_range_test[::2])
print("Range of y coordinates in test data: ", landmarks_range_test[1::2])

# Find the range of the image dimensions
image_range = np.array([1, 1])  # Since all images are normalized to [0,1]
print("Image range: ", image_range)
# Out:
# Range of x coordinates in train data:  [0.24770904 0.2455475  0.21195495 0.3001253  0.18858916 0.30204564
#  0.25743538 0.32714456 0.2068975  0.37343583 0.33728275 0.42601708
#  0.4094518  0.2847543  0.30615094]
# Range of y coordinates in train data:  [0.23228565 0.21766388 0.20833561 0.24378961 0.19413832 0.23512885
#  0.2545213  0.32990867 0.23926936 0.32790154 0.35869095 0.3921914
#  0.38284343 0.3874718  0.40184045]
# Range of x coordinates in validation data:  [0.2762287  0.16548106 0.23932487 0.30294508 0.18124372 0.15884888
#  0.3098283  0.3554799  0.25662467 0.17586568 0.38993657 0.29606566
#  0.28550935 0.28382248 0.28200212]
# Range of y coordinates in validation data:  [0.1715844  0.20588335 0.15711609 0.23690692 0.17125025 0.24250722
#  0.20981152 0.33408678 0.20284823 0.28002593 0.29478893 0.30648702
#  0.26343924 0.33945024 0.28691435]
# Range of x coordinates in test data:  [0.12574387 0.14884283 0.12396657 0.18157959 0.13101271 0.17166944
#  0.21898112 0.24192876 0.18511435 0.2634657  0.26247552 0.27217054
#  0.30166006 0.27004376 0.27723926]
# Range of y coordinates in test data:  [0.1889197  0.17267394 0.16171226 0.20056838 0.1588965  0.20215529
#  0.2370105  0.2389017  0.20316787 0.22959407 0.25076437 0.2299763
#  0.21132803 0.28952336 0.28143668]
# Image range:  [1 1]

# %% [markdown]
# # (3) CNN Model

# %% [markdown]
# ### (3)-1. Model Architecture

# %%
from tensorflow.keras import Model, regularizers
from tensorflow.keras.layers import Input, Conv2D, MaxPool2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import LearningRateScheduler

def create_model():
    inputs = Input(shape=(96, 96, 1))

    x = Conv2D(32, kernel_size=3, padding='same', activation='relu', 
               kernel_regularizer=regularizers.l2(0.01))(inputs)
    x = MaxPool2D(pool_size=2, strides=2)(x)

    x = Conv2D(32, kernel_size=3, padding='same', activation='relu', 
               kernel_regularizer=regularizers.l2(0.01))(x)
    x = MaxPool2D(pool_size=2, strides=2)(x)

    x = Conv2D(64, kernel_size=3, padding='same', activation='relu', 
               kernel_regularizer=regularizers.l2(0.01))(x)
    x = MaxPool2D(pool_size=2, strides=2)(x)

    x = Conv2D(64, kernel_size=3, padding='same', activation='relu', 
               kernel_regularizer=regularizers.l2(0.01))(x)
    x = MaxPool2D(pool_size=2, strides=2)(x)

    x = Flatten()(x)
    x = Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)

    # 15 facial landmarks * 2 for the x and y coordinates = 30
    outputs = Dense(30)(x)

    return Model(inputs=inputs, outputs=outputs)

model = create_model()
# Out:
# Metal device set to: Apple M2 Pro

# %% [markdown]
# ### (3)-2. Loss-function: L2-loss + cosine-loss

# %%
def customized_loss(y_true, y_pred, lambda_weight=0.5):
    l2_loss = tf.reduce_mean(tf.square(y_true - y_pred))
    cosine_loss = 1 - tf.reduce_mean(tf.keras.losses.cosine_similarity(y_true, y_pred))

    return l2_loss + lambda_weight * cosine_loss

# %% [markdown]
# ### (3)-3. Model fit

# %%
# Set learning rate schedule
lr_schedule = LearningRateScheduler(lambda epoch: 1e-6 * 10**(epoch / 20))

model.compile(optimizer='adam', loss=customized_loss)

# %% [markdown]
# ### (3)-4. Model train: Creating 'Callbacks' & training

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# Create callbacks
checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='min')

callbacks_list = [checkpoint, early_stop]

# Train the model
history = model.fit(train_images, train_landmarks, validation_data=(val_images, val_landmarks), 
                    batch_size=32, epochs=100, callbacks=callbacks_list)

# Load the best model
model.load_weights('best_model.h5')
# Out:
# Epoch 1/100
# 41/41 [==============================] - ETA: 0s - loss: 1.8158
# Epoch 1: val_loss improved from inf to 0.95471, saving model to best_model.h5
# 41/41 [==============================] - 2s 37ms/step - loss: 1.8158 - val_loss: 0.9547
# Epoch 2/100
#  5/41 [==>...........................] - ETA: 0s - loss: 0.9155
# /Users/sh_oh/anaconda3/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 40/41 [============================>.] - ETA: 0s - loss: 0.6885
# Epoch 2: val_loss improved from 0.95471 to 0.50638, saving model to best_model.h5
# 41/41 [==============================] - 1s 29ms/step - loss: 0.6879 - val_loss: 0.5064
# Epoch 3/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.4385
# Epoch 3: val_loss improved from 0.50638 to 0.38189, saving model to best_model.h5
# 41/41 [==============================] - 1s 29ms/step - loss: 0.4370 - val_loss: 0.3819
# Epoch 4/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3572
# Epoch 4: val_loss improved from 0.38189 to 0.33507, saving model to best_model.h5
# 41/41 [==============================] - 1s 29ms/step - loss: 0.3572 - val_loss: 0.3351
# Epoch 5/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.3247
# Epoch 5: val_loss improved from 0.33507 to 0.31323, saving model to best_model.h5
# 41/41 [==============================] - 1s 26ms/step - loss: 0.3245 - val_loss: 0.3132
# Epoch 6/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.3091
# Epoch 6: val_loss improved from 0.31323 to 0.30258, saving model to best_model.h5
# 41/41 [==============================] - 1s 31ms/step - loss: 0.3089 - val_loss: 0.3026
# Epoch 7/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.3006
# Epoch 7: val_loss improved from 0.30258 to 0.29595, saving model to best_model.h5
# 41/41 [==============================] - 1s 30ms/step - loss: 0.3004 - val_loss: 0.2960
# Epoch 8/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.2969
# Epoch 8: val_loss improved from 0.29595 to 0.29290, saving model to best_model.h5
# 41/41 [==============================] - 1s 29ms/step - loss: 0.2969 - val_loss: 0.2929
# Epoch 9/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.2931
# Epoch 9: val_loss improved from 0.29290 to 0.29122, saving model to best_model.h5
# 41/41 [==============================] - 1s 29ms/step - loss: 0.2929 - val_loss: 0.2912
# Epoch 10/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.2917
# Epoch 10: val_loss improved from 0.29122 to 0.28953, saving model to best_model.h5
# 41/41 [==============================] - 1s 31ms/step - loss: 0.2918 - val_loss: 0.2895
# Epoch 11/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.2907
# Epoch 11: val_loss improved from 0.28953 to 0.28884, saving model to best_model.h5
# 41/41 [==============================] - 1s 28ms/step - loss: 0.2907 - val_loss: 0.2888
# Epoch 12/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.2897
# Epoch 12: val_loss improved from 0.28884 to 0.28818, saving model to best_model.h5
# 41/41 [==============================] - 1s 28ms/step - loss: 0.2896 - val_loss: 0.2882
# Epoch 13/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.2901
# Epoch 13: val_loss improved from 0.28818 to 0.28812, saving model to best_model.h5
# 41/41 [==============================] - 1s 30ms/step - loss: 0.2900 - val_loss: 0.2881
# Epoch 14/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.2888
# Epoch 14: val_loss improved from 0.28812 to 0.28768, saving model to best_model.h5
# 41/41 [==============================] - 1s 28ms/step - loss: 0.2888 - val_loss: 0.2877
# Epoch 15/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.2894
# Epoch 15: val_loss did not improve from 0.28768
# 41/41 [==============================] - 1s 28ms/step - loss: 0.2894 - val_loss: 0.2914
# Epoch 16/100
# 41/41 [==============================] - ETA: 0s - loss: 0.2900
# Epoch 16: val_loss improved from 0.28768 to 0.28766, saving model to best_model.h5
# 41/41 [==============================] - 1s 31ms/step - loss: 0.2900 - val_loss: 0.2877
# Epoch 17/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.2885
# Epoch 17: val_loss did not improve from 0.28766
# 41/41 [==============================] - 1s 28ms/step - loss: 0.2885 - val_loss: 0.2892
# Epoch 18/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.2892
# Epoch 18: val_loss improved from 0.28766 to 0.28705, saving model to best_model.h5
# 41/41 [==============================] - 1s 28ms/step - loss: 0.2892 - val_loss: 0.2871
# Epoch 19/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.2880
# Epoch 19: val_loss did not improve from 0.28705
# 41/41 [==============================] - 1s 28ms/step - loss: 0.2880 - val_loss: 0.2871
# Epoch 20/100
# 41/41 [==============================] - ETA: 0s - loss: 0.2879
# Epoch 20: val_loss did not improve from 0.28705
# 41/41 [==============================] - 1s 29ms/step - loss: 0.2879 - val_loss: 0.2873
# Epoch 21/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.2876
# Epoch 21: val_loss improved from 0.28705 to 0.28699, saving model to best_model.h5
# 41/41 [==============================] - 1s 30ms/step - loss: 0.2876 - val_loss: 0.2870
# Epoch 22/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.2874
# Epoch 22: val_loss did not improve from 0.28699
# 41/41 [==============================] - 1s 29ms/step - loss: 0.2874 - val_loss: 0.2881
# Epoch 23/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.2900
# Epoch 23: val_loss did not improve from 0.28699
# 41/41 [==============================] - 1s 30ms/step - loss: 0.2900 - val_loss: 0.2876
# Epoch 24/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.2880
# Epoch 24: val_loss improved from 0.28699 to 0.28646, saving model to best_model.h5
# 41/41 [==============================] - 1s 29ms/step - loss: 0.2880 - val_loss: 0.2865
# Epoch 25/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.2875
# Epoch 25: val_loss did not improve from 0.28646
# 41/41 [==============================] - 1s 30ms/step - loss: 0.2875 - val_loss: 0.2868
# Epoch 26/100
# 41/41 [==============================] - ETA: 0s - loss: 0.2874
# Epoch 26: val_loss did not improve from 0.28646
# 41/41 [==============================] - 1s 28ms/step - loss: 0.2874 - val_loss: 0.2868
# Epoch 27/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.2944
# Epoch 27: val_loss did not improve from 0.28646
# 41/41 [==============================] - 1s 25ms/step - loss: 0.2944 - val_loss: 0.2914
# Epoch 28/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.2909
# Epoch 28: val_loss did not improve from 0.28646
# 41/41 [==============================] - 1s 29ms/step - loss: 0.2908 - val_loss: 0.2884
# Epoch 29/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.2890
# Epoch 29: val_loss did not improve from 0.28646
# 41/41 [==============================] - 1s 28ms/step - loss: 0.2890 - val_loss: 0.2873
# Epoch 30/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.2878
# Epoch 30: val_loss did not improve from 0.28646
# 41/41 [==============================] - 1s 28ms/step - loss: 0.2878 - val_loss: 0.2869
# Epoch 31/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.2874
# Epoch 31: val_loss did not improve from 0.28646
# 41/41 [==============================] - 1s 28ms/step - loss: 0.2874 - val_loss: 0.2896
# Epoch 32/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.2879
# Epoch 32: val_loss improved from 0.28646 to 0.28627, saving model to best_model.h5
# 41/41 [==============================] - 1s 30ms/step - loss: 0.2878 - val_loss: 0.2863
# Epoch 33/100
# 41/41 [==============================] - ETA: 0s - loss: 0.2871
# Epoch 33: val_loss improved from 0.28627 to 0.28602, saving model to best_model.h5
# 41/41 [==============================] - 1s 28ms/step - loss: 0.2871 - val_loss: 0.2860
# Epoch 34/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.2870
# Epoch 34: val_loss improved from 0.28602 to 0.28599, saving model to best_model.h5
# 41/41 [==============================] - 1s 29ms/step - loss: 0.2870 - val_loss: 0.2860
# Epoch 35/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.2870
# Epoch 35: val_loss did not improve from 0.28599
# 41/41 [==============================] - 1s 30ms/step - loss: 0.2869 - val_loss: 0.2865
# Epoch 36/100
# 41/41 [==============================] - ETA: 0s - loss: 0.2872
# Epoch 36: val_loss did not improve from 0.28599
# 41/41 [==============================] - 1s 27ms/step - loss: 0.2872 - val_loss: 0.2871
# Epoch 37/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.2870
# Epoch 37: val_loss did not improve from 0.28599
# 41/41 [==============================] - 1s 30ms/step - loss: 0.2870 - val_loss: 0.2867
# Epoch 38/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.2872
# Epoch 38: val_loss did not improve from 0.28599
# 41/41 [==============================] - 1s 27ms/step - loss: 0.2872 - val_loss: 0.2861
# Epoch 39/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.2871
# Epoch 39: val_loss did not improve from 0.28599
# 41/41 [==============================] - 1s 28ms/step - loss: 0.2871 - val_loss: 0.2863
# Epoch 40/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.2871
# Epoch 40: val_loss did not improve from 0.28599
# 41/41 [==============================] - 1s 28ms/step - loss: 0.2871 - val_loss: 0.2862
# Epoch 41/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.2870
# Epoch 41: val_loss did not improve from 0.28599
# 41/41 [==============================] - 1s 27ms/step - loss: 0.2869 - val_loss: 0.2869
# Epoch 42/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.2869
# Epoch 42: val_loss did not improve from 0.28599
# 41/41 [==============================] - 1s 30ms/step - loss: 0.2870 - val_loss: 0.2864
# Epoch 43/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.2870
# Epoch 43: val_loss improved from 0.28599 to 0.28584, saving model to best_model.h5
# 41/41 [==============================] - 1s 29ms/step - loss: 0.2870 - val_loss: 0.2858
# Epoch 44/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.2869
# Epoch 44: val_loss did not improve from 0.28584
# 41/41 [==============================] - 1s 29ms/step - loss: 0.2869 - val_loss: 0.2882
# Epoch 45/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.2870
# Epoch 45: val_loss did not improve from 0.28584
# 41/41 [==============================] - 1s 29ms/step - loss: 0.2869 - val_loss: 0.2867
# Epoch 46/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.2870
# Epoch 46: val_loss did not improve from 0.28584
# 41/41 [==============================] - 1s 25ms/step - loss: 0.2870 - val_loss: 0.2867
# Epoch 47/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.2869
# Epoch 47: val_loss did not improve from 0.28584
# 41/41 [==============================] - 1s 28ms/step - loss: 0.2869 - val_loss: 0.2866
# Epoch 48/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.2868
# Epoch 48: val_loss did not improve from 0.28584
# 41/41 [==============================] - 1s 27ms/step - loss: 0.2869 - val_loss: 0.2865
# Epoch 49/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.2868
# Epoch 49: val_loss did not improve from 0.28584
# 41/41 [==============================] - 1s 26ms/step - loss: 0.2868 - val_loss: 0.2872
# Epoch 50/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.2870
# Epoch 50: val_loss did not improve from 0.28584
# 41/41 [==============================] - 1s 27ms/step - loss: 0.2869 - val_loss: 0.2898
# Epoch 51/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.2873
# Epoch 51: val_loss did not improve from 0.28584
# 41/41 [==============================] - 1s 26ms/step - loss: 0.2873 - val_loss: 0.2859
# Epoch 52/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.2868
# Epoch 52: val_loss did not improve from 0.28584
# 41/41 [==============================] - 1s 28ms/step - loss: 0.2868 - val_loss: 0.2868
# Epoch 53/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.2868
# Epoch 53: val_loss did not improve from 0.28584
# 41/41 [==============================] - 1s 27ms/step - loss: 0.2869 - val_loss: 0.2864
# Epoch 53: early stopping

# %% [markdown]
# ### (3)-5. calculate validation loss & prediction error

# %%
# Calculate the validation loss
val_loss = model.evaluate(val_images, val_landmarks)
print("Validation loss: ", val_loss)

# Calculate the prediction error on the validation set
val_predictions = model.predict(val_images)
prediction_error = np.mean(np.abs(val_predictions - val_landmarks))
print("Validation prediction error: ", prediction_error)

# Plot the training and validation loss
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Over Time')
plt.legend()
plt.show()
# Out:
# 14/14 [==============================] - 0s 11ms/step - loss: 0.2858
# Validation loss:  0.28583693504333496
# 14/14 [==============================] - 0s 8ms/step
# Validation prediction error:  0.49582592
