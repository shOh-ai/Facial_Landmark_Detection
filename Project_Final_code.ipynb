# %% [markdown]
# # (1) Dataset Visualization

# %%
import scipy.io as io
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf

# Set the random seed for TensorFlow
tf.random.set_seed(101)

# load the data
data = io.loadmat("face_landmark.mat")
images = data["images"]
landmarks = data["landmarks"]

print("im_shape:", images.shape)
print("landmarks_shape:", landmarks.shape)

np.random.seed(101)

fig, ax = plt.subplots(2, 2, figsize=(10,10))  # create a 2x2 grid of subplots
ax = ax.ravel()

for i in range(4):  # loop over the 4 subplots
    id = np.random.randint(len(images))  # generate a random index
    im = images[id]
    keypoints = landmarks[id]

    ax[i].imshow(im, cmap="gray")
    for point in keypoints:
        ax[i].plot(point[0], point[1], "r+")

plt.show()
# Out:
# im_shape: (2140, 96, 96)
# landmarks_shape: (2140, 15, 2)

# %% [markdown]
# # (2) Preprocessing

# %% [markdown]
# ### (2)-1. Data_split: train(60%), validation(20%), test(20%)

# %%
from sklearn.model_selection import train_test_split

# 60% training, 40% for validation/testing
train_images, val_test_images, train_landmarks, val_test_landmarks = train_test_split(images, landmarks, test_size=0.4, random_state=101)

# Split the 40% equally to validation and testing (20% each)
val_images, test_images, val_landmarks, test_landmarks = train_test_split(val_test_images, val_test_landmarks, test_size=0.5, random_state=101)

# reshape landmarks
train_landmarks = train_landmarks.reshape(-1, 30)
val_landmarks = val_landmarks.reshape(-1, 30)
test_landmarks = test_landmarks.reshape(-1, 30)

print("Training set:", train_images.shape, train_landmarks.shape)
print("Validation set:", val_images.shape, val_landmarks.shape)
print("Testing set:", test_images.shape, test_landmarks.shape)
# Out:
# Training set: (1284, 96, 96) (1284, 30)
# Validation set: (428, 96, 96) (428, 30)
# Testing set: (428, 96, 96) (428, 30)

# %% [markdown]
# ### (2)-2. Normalization & Reshaping

# %%
# Normalization
train_images = train_images / 255.0
val_images = val_images / 255.0
test_images = test_images / 255.0

# Scale landmarks
train_landmarks = train_landmarks / 96.0
val_landmarks = val_landmarks / 96.0
test_landmarks = test_landmarks / 96.0

# Reshaping
train_images = train_images.reshape(-1, 96, 96, 1)
val_images = val_images.reshape(-1, 96, 96, 1)
test_images = test_images.reshape(-1, 96, 96, 1)

print("After preprocessing:")
print("Training set:", train_images.shape, train_landmarks.shape)
print("Validation set:", val_images.shape, val_landmarks.shape)
print("Testing set:", test_images.shape, test_landmarks.shape)
# Out:
# After preprocessing:
# Training set: (1284, 96, 96, 1) (1284, 30)
# Validation set: (428, 96, 96, 1) (428, 30)
# Testing set: (428, 96, 96, 1) (428, 30)

# %%
# Find the range of the landmarks coordinates
landmarks_range_train = np.ptp(train_landmarks, axis=0)
landmarks_range_val = np.ptp(val_landmarks, axis=0)
landmarks_range_test = np.ptp(test_landmarks, axis=0)

print("Range of x coordinates in train data: ", landmarks_range_train[::2])
print("Range of y coordinates in train data: ", landmarks_range_train[1::2])

print("Range of x coordinates in validation data: ", landmarks_range_val[::2])
print("Range of y coordinates in validation data: ", landmarks_range_val[1::2])

print("Range of x coordinates in test data: ", landmarks_range_test[::2])
print("Range of y coordinates in test data: ", landmarks_range_test[1::2])

# Find the range of the image dimensions
image_range = np.array([1, 1])  # Since all images are normalized to [0,1]
print("Image range: ", image_range)
# Out:
# Range of x coordinates in train data:  [0.24770904 0.2455475  0.21195495 0.3001253  0.18858916 0.30204564
#  0.25743538 0.32714456 0.2068975  0.37343583 0.33728275 0.42601708
#  0.4094518  0.2847543  0.30615094]
# Range of y coordinates in train data:  [0.23228565 0.21766388 0.20833561 0.24378961 0.19413832 0.23512885
#  0.2545213  0.32990867 0.23926936 0.32790154 0.35869095 0.3921914
#  0.38284343 0.3874718  0.40184045]
# Range of x coordinates in validation data:  [0.2762287  0.16548106 0.23932487 0.30294508 0.18124372 0.15884888
#  0.3098283  0.3554799  0.25662467 0.17586568 0.38993657 0.29606566
#  0.28550935 0.28382248 0.28200212]
# Range of y coordinates in validation data:  [0.1715844  0.20588335 0.15711609 0.23690692 0.17125025 0.24250722
#  0.20981152 0.33408678 0.20284823 0.28002593 0.29478893 0.30648702
#  0.26343924 0.33945024 0.28691435]
# Range of x coordinates in test data:  [0.12574387 0.14884283 0.12396657 0.18157959 0.13101271 0.17166944
#  0.21898112 0.24192876 0.18511435 0.2634657  0.26247552 0.27217054
#  0.30166006 0.27004376 0.27723926]
# Range of y coordinates in test data:  [0.1889197  0.17267394 0.16171226 0.20056838 0.1588965  0.20215529
#  0.2370105  0.2389017  0.20316787 0.22959407 0.25076437 0.2299763
#  0.21132803 0.28952336 0.28143668]
# Image range:  [1 1]

# %% [markdown]
# # (3) CNN Model

# %% [markdown]
# ### (3)-1. Model Architecture

# %%
from tensorflow.keras import Model, regularizers
from tensorflow.keras.layers import Input, Conv2D, MaxPool2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import LearningRateScheduler

def create_model():
    inputs = Input(shape=(96, 96, 1))

    x = Conv2D(32, kernel_size=3, padding='same', activation='relu', 
               kernel_regularizer=regularizers.l2(0.0175))(inputs)
    x = MaxPool2D(pool_size=2, strides=2)(x)
    x = Dropout(0.6)(x)

    x = Conv2D(32, kernel_size=3, padding='same', activation='relu', 
               kernel_regularizer=regularizers.l2(0.0175))(x)
    x = MaxPool2D(pool_size=2, strides=2)(x)
    x = Dropout(0.6)(x)

    x = Conv2D(64, kernel_size=3, padding='same', activation='relu', 
               kernel_regularizer=regularizers.l2(0.0175))(x)
    x = MaxPool2D(pool_size=2, strides=2)(x)
    x = Dropout(0.6)(x)

    x = Conv2D(64, kernel_size=3, padding='same', activation='relu', 
               kernel_regularizer=regularizers.l2(0.0175))(x)
    x = MaxPool2D(pool_size=2, strides=2)(x)
    x = Dropout(0.6)(x)

    x = Flatten()(x)
    x = Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.0175))(x)

    # 15 facial landmarks * 2 for the x and y coordinates = 30
    outputs = Dense(30)(x)

    return Model(inputs=inputs, outputs=outputs)

model = create_model()
# Out:
# Metal device set to: Apple M2 Pro

# %%
#!pip install pydot
#!pip install graphviz
from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes=True, to_file='model.png')

# %% [markdown]
# ### (3)-2. Loss-function: L1-loss

# %%
def l2_loss(y_true, y_pred):
    return tf.reduce_mean(tf.square(y_true - y_pred))

# %% [markdown]
# ### (3)-3. Model fit

# %%
# Set learning rate schedule
lr_schedule = LearningRateScheduler(lambda epoch: 1e-6 * 10**(epoch / 20))

model.compile(optimizer='adam', loss=l2_loss)

# %% [markdown]
# ### (3)-4. Model train: Creating 'Callbacks' & training

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# Create callbacks
checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='min')

callbacks_list = [checkpoint, early_stop]

# Train the model
history = model.fit(train_images, train_landmarks, validation_data=(val_images, val_landmarks), 
                    batch_size=32, epochs=100, callbacks=callbacks_list)

# Load the best model
model.load_weights('best_model.h5')
# Out:
# Epoch 1/100
# 41/41 [==============================] - ETA: 0s - loss: 2.1127
# Epoch 1: val_loss improved from inf to 0.56629, saving model to best_model.h5
# 41/41 [==============================] - 2s 34ms/step - loss: 2.1127 - val_loss: 0.5663
# Epoch 2/100
#  6/41 [===>..........................] - ETA: 0s - loss: 0.4601
# /Users/sh_oh/anaconda3/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 40/41 [============================>.] - ETA: 0s - loss: 0.2224
# Epoch 2: val_loss improved from 0.56629 to 0.07281, saving model to best_model.h5
# 41/41 [==============================] - 1s 26ms/step - loss: 0.2219 - val_loss: 0.0728
# Epoch 3/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0327
# Epoch 3: val_loss improved from 0.07281 to 0.01687, saving model to best_model.h5
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0322 - val_loss: 0.0169
# Epoch 4/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0097
# Epoch 4: val_loss improved from 0.01687 to 0.00722, saving model to best_model.h5
# 41/41 [==============================] - 1s 27ms/step - loss: 0.0097 - val_loss: 0.0072
# Epoch 5/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 5: val_loss improved from 0.00722 to 0.00508, saving model to best_model.h5
# 41/41 [==============================] - 1s 28ms/step - loss: 0.0055 - val_loss: 0.0051
# Epoch 6/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0041
# Epoch 6: val_loss improved from 0.00508 to 0.00417, saving model to best_model.h5
# 41/41 [==============================] - 1s 29ms/step - loss: 0.0041 - val_loss: 0.0042
# Epoch 7/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0034
# Epoch 7: val_loss improved from 0.00417 to 0.00302, saving model to best_model.h5
# 41/41 [==============================] - 1s 27ms/step - loss: 0.0034 - val_loss: 0.0030
# Epoch 8/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0030
# Epoch 8: val_loss improved from 0.00302 to 0.00257, saving model to best_model.h5
# 41/41 [==============================] - 1s 27ms/step - loss: 0.0030 - val_loss: 0.0026
# Epoch 9/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 9: val_loss did not improve from 0.00257
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0026 - val_loss: 0.0028
# Epoch 10/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 10: val_loss did not improve from 0.00257
# 41/41 [==============================] - 1s 30ms/step - loss: 0.0023 - val_loss: 0.0032
# Epoch 11/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 11: val_loss improved from 0.00257 to 0.00197, saving model to best_model.h5
# 41/41 [==============================] - 1s 26ms/step - loss: 0.0026 - val_loss: 0.0020
# Epoch 12/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 12: val_loss did not improve from 0.00197
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0021 - val_loss: 0.0025
# Epoch 13/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 13: val_loss did not improve from 0.00197
# 41/41 [==============================] - 1s 26ms/step - loss: 0.0020 - val_loss: 0.0038
# Epoch 14/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0021
# Epoch 14: val_loss improved from 0.00197 to 0.00177, saving model to best_model.h5
# 41/41 [==============================] - 1s 26ms/step - loss: 0.0021 - val_loss: 0.0018
# Epoch 15/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 15: val_loss improved from 0.00177 to 0.00157, saving model to best_model.h5
# 41/41 [==============================] - 1s 27ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 16/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 16: val_loss did not improve from 0.00157
# 41/41 [==============================] - 1s 27ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 17/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 17: val_loss improved from 0.00157 to 0.00154, saving model to best_model.h5
# 41/41 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 18/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 18: val_loss did not improve from 0.00154
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 19/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0017
# Epoch 19: val_loss improved from 0.00154 to 0.00137, saving model to best_model.h5
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 20/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0016
# Epoch 20: val_loss did not improve from 0.00137
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 21/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 21: val_loss did not improve from 0.00137
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 22/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 22: val_loss did not improve from 0.00137
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 23/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 23: val_loss did not improve from 0.00137
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 24/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0015
# Epoch 24: val_loss did not improve from 0.00137
# 41/41 [==============================] - 1s 28ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 25/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 25: val_loss improved from 0.00137 to 0.00133, saving model to best_model.h5
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 26/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0015
# Epoch 26: val_loss improved from 0.00133 to 0.00129, saving model to best_model.h5
# 41/41 [==============================] - 1s 28ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 27/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0014
# Epoch 27: val_loss improved from 0.00129 to 0.00126, saving model to best_model.h5
# 41/41 [==============================] - 1s 26ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 28/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0014
# Epoch 28: val_loss did not improve from 0.00126
# 41/41 [==============================] - 1s 26ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 29/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0015
# Epoch 29: val_loss improved from 0.00126 to 0.00117, saving model to best_model.h5
# 41/41 [==============================] - 1s 26ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 30/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0014
# Epoch 30: val_loss did not improve from 0.00117
# 41/41 [==============================] - 1s 26ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 31/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 31: val_loss did not improve from 0.00117
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 32/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0014
# Epoch 32: val_loss did not improve from 0.00117
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 33/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 33: val_loss did not improve from 0.00117
# 41/41 [==============================] - 1s 26ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 34/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0013
# Epoch 34: val_loss improved from 0.00117 to 0.00117, saving model to best_model.h5
# 41/41 [==============================] - 1s 26ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 35/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 35: val_loss did not improve from 0.00117
# 41/41 [==============================] - 1s 26ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 36/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 36: val_loss improved from 0.00117 to 0.00116, saving model to best_model.h5
# 41/41 [==============================] - 1s 26ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 37/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0013
# Epoch 37: val_loss did not improve from 0.00116
# 41/41 [==============================] - 1s 26ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 38/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 38: val_loss improved from 0.00116 to 0.00114, saving model to best_model.h5
# 41/41 [==============================] - 1s 27ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 39/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0012
# Epoch 39: val_loss did not improve from 0.00114
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 40/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 40: val_loss did not improve from 0.00114
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 41/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0012
# Epoch 41: val_loss did not improve from 0.00114
# 41/41 [==============================] - 1s 26ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 42/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 42: val_loss did not improve from 0.00114
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 43/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 43: val_loss improved from 0.00114 to 0.00112, saving model to best_model.h5
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 44/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 44: val_loss did not improve from 0.00112
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 45/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0014
# Epoch 45: val_loss did not improve from 0.00112
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 46/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 46: val_loss did not improve from 0.00112
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 47/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 47: val_loss did not improve from 0.00112
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 48/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 48: val_loss did not improve from 0.00112
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 49/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 49: val_loss did not improve from 0.00112
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 50/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 50: val_loss did not improve from 0.00112
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 51/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0012
# Epoch 51: val_loss improved from 0.00112 to 0.00111, saving model to best_model.h5
# 41/41 [==============================] - 1s 26ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 52/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 52: val_loss did not improve from 0.00111
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 53/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 53: val_loss improved from 0.00111 to 0.00111, saving model to best_model.h5
# 41/41 [==============================] - 1s 26ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 54/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 54: val_loss improved from 0.00111 to 0.00111, saving model to best_model.h5
# 41/41 [==============================] - 1s 26ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 55/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 55: val_loss improved from 0.00111 to 0.00111, saving model to best_model.h5
# 41/41 [==============================] - 1s 26ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 56/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 56: val_loss did not improve from 0.00111
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 57/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0012
# Epoch 57: val_loss did not improve from 0.00111
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 58/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0012
# Epoch 58: val_loss did not improve from 0.00111
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 59/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0012
# Epoch 59: val_loss did not improve from 0.00111
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 60/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0012
# Epoch 60: val_loss did not improve from 0.00111
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 61/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 61: val_loss improved from 0.00111 to 0.00110, saving model to best_model.h5
# 41/41 [==============================] - 1s 26ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 62/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 62: val_loss did not improve from 0.00110
# 41/41 [==============================] - 1s 27ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 63/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 63: val_loss did not improve from 0.00110
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 64/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 64: val_loss did not improve from 0.00110
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 65/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 65: val_loss did not improve from 0.00110
# 41/41 [==============================] - 1s 27ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 66/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 66: val_loss did not improve from 0.00110
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 67/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0011
# Epoch 67: val_loss improved from 0.00110 to 0.00110, saving model to best_model.h5
# 41/41 [==============================] - 1s 27ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 68/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 68: val_loss did not improve from 0.00110
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 69/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0012
# Epoch 69: val_loss improved from 0.00110 to 0.00110, saving model to best_model.h5
# 41/41 [==============================] - 1s 28ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 70/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 70: val_loss did not improve from 0.00110
# 41/41 [==============================] - 1s 27ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 71/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0011
# Epoch 71: val_loss improved from 0.00110 to 0.00109, saving model to best_model.h5
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 72/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0011
# Epoch 72: val_loss did not improve from 0.00109
# 41/41 [==============================] - 1s 26ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 73/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0011
# Epoch 73: val_loss did not improve from 0.00109
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 74/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 74: val_loss did not improve from 0.00109
# 41/41 [==============================] - 1s 26ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 75/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 75: val_loss did not improve from 0.00109
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 76/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 76: val_loss did not improve from 0.00109
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 77/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0012
# Epoch 77: val_loss did not improve from 0.00109
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 78/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0012
# Epoch 78: val_loss improved from 0.00109 to 0.00109, saving model to best_model.h5
# 41/41 [==============================] - 1s 26ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 79/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 79: val_loss did not improve from 0.00109
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 80/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0012
# Epoch 80: val_loss did not improve from 0.00109
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 81/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 81: val_loss did not improve from 0.00109
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 82/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0012
# Epoch 82: val_loss did not improve from 0.00109
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 83/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0011
# Epoch 83: val_loss did not improve from 0.00109
# 41/41 [==============================] - 1s 26ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 84/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 84: val_loss improved from 0.00109 to 0.00109, saving model to best_model.h5
# 41/41 [==============================] - 1s 26ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 85/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 85: val_loss did not improve from 0.00109
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 86/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 86: val_loss did not improve from 0.00109
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 87/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 87: val_loss did not improve from 0.00109
# 41/41 [==============================] - 1s 26ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 88/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.0011
# Epoch 88: val_loss did not improve from 0.00109
# 41/41 [==============================] - 1s 26ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 89/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 89: val_loss did not improve from 0.00109
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 90/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 90: val_loss did not improve from 0.00109
# 41/41 [==============================] - 1s 28ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 91/100
# 40/41 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 91: val_loss did not improve from 0.00109
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 92/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 92: val_loss did not improve from 0.00109
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 93/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 93: val_loss did not improve from 0.00109
# 41/41 [==============================] - 1s 27ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 94/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 94: val_loss did not improve from 0.00109
# 41/41 [==============================] - 1s 26ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 94: early stopping

# %% [markdown]
# ### (3)-5. calculate validation loss & prediction error

# %%
# Calculate the validation loss
val_loss = model.evaluate(val_images, val_landmarks)
print("Validation loss: ", val_loss)

# Calculate the prediction error on the validation set
val_predictions = model.predict(val_images)
prediction_error = np.mean(np.abs(val_predictions - val_landmarks))
print("Validation prediction error: ", prediction_error)

# Plot the training and validation loss
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Over Time')
plt.legend()
plt.show()
# Out:
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0011
# Validation loss:  0.0010891745332628489
# 14/14 [==============================] - 0s 8ms/step
# Validation prediction error:  0.02393005

# %% [markdown]
# # (4) Model Test & Result

# %% [markdown]
# ### (4)-1. Evaluate model on the test data

# %%
test_loss = model.evaluate(test_images, test_landmarks, verbose=0)
print("Test loss: ", test_loss)
# Out:
# Test loss:  0.0010353944962844253

# %% [markdown]
# ### (4)-2. Calculate Prediction Error

# %%
# Getting predictions
train_preds = model.predict(train_images)
test_preds = model.predict(test_images)

# Calculating and printing prediction error
train_prediction_error = np.mean(np.abs(train_preds - train_landmarks))
test_prediction_error = np.mean(np.abs(test_preds - test_landmarks))
print(f"Train Prediction Error: {train_prediction_error}")
print(f"Test Prediction Error: {test_prediction_error}")
# Out:
# 41/41 [==============================] - 0s 7ms/step
# 14/14 [==============================] - 0s 7ms/step
# Train Prediction Error: 0.024436308071017265
# Test Prediction Error: 0.023817120119929314

# %% [markdown]
# ### (4)-3. Load few good and bad prediction examples & Visualize

# %%
train_landmarks = train_landmarks * 96
test_landmarks = test_landmarks * 96
train_preds = train_preds * 96
test_preds = test_preds * 96

# %%
# Function for visualizing predictions
def visualize_predictions(image, true_landmarks, pred_landmarks):
    plt.imshow(image.squeeze(), cmap='gray')  # Also need to squeeze the image for visualization

    # Reshape landmarks for plotting
    true_landmarks = true_landmarks.reshape(-1, 2)
    pred_landmarks = pred_landmarks.reshape(-1, 2)

    for point in true_landmarks:
        plt.plot(point[0], point[1], 'r+')
    for point in pred_landmarks:
        plt.plot(point[0], point[1], 'b+')
    plt.show()

# Load few good and bad predictions
test_error_per_sample = np.mean(np.abs(test_preds - test_landmarks), axis=1)
sorted_error_idx = np.argsort(test_error_per_sample)
good_preds = sorted_error_idx[:5]
bad_preds = sorted_error_idx[-5:]    

# Visualizing good predictions
print("Good Predictions:")
for idx in good_preds:
    visualize_predictions(test_images[idx], test_landmarks[idx], test_preds[idx])

# Visualizing bad predictions
print("Bad Predictions:")
for idx in bad_preds:
    visualize_predictions(test_images[idx], test_landmarks[idx], test_preds[idx])
# Out:
# Good Predictions:
# Bad Predictions:
